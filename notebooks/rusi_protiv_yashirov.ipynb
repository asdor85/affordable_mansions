# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/secondary_market.csv')
df.head()
# Out:
#         id date_posted    district okrug       lat       lon  total_area  \
# 0  S000001  2024-11-23     Begovoy   SAO  55.79533  37.55519        71.0
# 1  S000002  2025-08-13   Sokolniki   VAO  55.79695  37.68875        79.6
# 2  S000003  2022-05-06  Sosenskoye   NAO  55.54901  37.43118        74.0
# 3  S000004  2025-04-08    Sviblovo  SVAO  55.86462  37.61471        52.3
# 4  S000005  2023-07-16     Begovoy   SAO  55.79429  37.54631        62.2
#
#    living_area  kitchen_area  rooms  ...     renovation    metro_station  \
# 0         46.5           6.1      2  ...       cosmetic            Sokol
# 1         52.8          10.8      3  ...  no_renovation        Sokolniki
# 2         42.2           8.9      2  ...       cosmetic         Polyanka
# 3         34.0           6.0      1  ...           euro         Sviblovo
# 4         38.3          13.1      2  ...       cosmetic  Sapyornoye Pole
#
#                      metro_line metro_distance_min  metro_distance_type  \
# ...

# %%
df.shape
# Out:
# (50000, 26)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        50000 non-null  str
#  1   date_posted               50000 non-null  str
#  2   district                  50000 non-null  str
#  3   okrug                     50000 non-null  str
#  4   lat                       50000 non-null  float64
#  5   lon                       50000 non-null  float64
#  6   total_area                50000 non-null  float64
#  7   living_area               50000 non-null  float64
#  8   kitchen_area              50000 non-null  float64
#  9   rooms                     50000 non-null  int64
#  10  floor                     50000 non-null  int64
#  11  total_floors              50000 non-null  int64
#  12  building_year             50000 non-null  int64
#  13  building_type             50000 non-null  str
# ...

# %%
df.describe()
# Out:
#                 lat           lon    total_area   living_area  kitchen_area  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean      55.712683     37.543657     67.053158     41.883782     11.244650
# std        0.143998      0.180338     17.309579     11.209233      2.855538
# min       55.234080     36.699230     20.900000     12.600000      6.000000
# 25%       55.635415     37.467110     54.400000     33.700000      9.200000
# 50%       55.740110     37.565840     65.100000     40.600000     11.100000
# 75%       55.817490     37.652020     77.500000     48.500000     13.100000
# max       56.020470     37.919860    134.300000     89.200000     24.800000
#
#               rooms         floor  total_floors  building_year  \
# count  50000.000000  50000.000000   50000.00000    50000.00000
# mean       2.134900      7.475420      14.00086     1988.22008
# std        1.023153      5.530469       6.53193       23.57096
# ...

# %%
df[['price_rub', 'total_area','rooms', 'to_center_km', 'building_year']].hist(bins=50, figsize=(12,8))
plt.tight_layout()
plt.show()
